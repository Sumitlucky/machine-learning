# %%
import numpy as np
import pandas as pd

# %%
arr1 = pd.Series([1,3,5,np.nan,6,8])
print(arr1)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates  = pd.date_range('20250918',periods=10)
print(dates)
# Out:
# DatetimeIndex(['2025-09-18', '2025-09-19', '2025-09-20', '2025-09-21',
#                '2025-09-22', '2025-09-23', '2025-09-24', '2025-09-25',
#                '2025-09-26', '2025-09-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
dataFrame  = pd.DataFrame(np.random.randn(10,4),index=dates,columns=list('ABCD'))
print(dataFrame)
# Out:
#                    A         B         C         D
# 2025-09-18  2.292047 -0.744923  0.619169 -0.256812
# 2025-09-19  0.460586  2.594236  0.754036 -0.631626
# 2025-09-20  0.568698 -2.323264 -1.328791 -0.400042
# 2025-09-21  1.133320 -0.284506 -0.774017  0.141663
# 2025-09-22 -2.205083 -1.111078 -0.051131  0.977213
# 2025-09-23  0.835417  2.535955  0.583963  0.940525
# 2025-09-24  1.712264  0.112078 -0.241303  0.392268
# 2025-09-25  0.192098 -1.178949  0.357518 -0.839257
# 2025-09-26 -0.886926 -0.595525 -1.674389 -1.587719
# 2025-09-27 -1.097523 -0.771856  0.279459 -1.533105

# %%
dataFrame2 = pd.DataFrame(
    {
    "A" : 1.0,
    "B" : pd.Timestamp("20250918"),
    "C" : pd.Series(1,index=list(range(4)),dtype="float32"),
    "D" : np.array([3]*4,dtype="int32"),
    "E" : pd.Categorical(["test","train","test","train"]),
    "F" : "foo"
    }
 )
print(dataFrame2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2025-09-18  1.0  3   test  foo
# 1  1.0 2025-09-18  1.0  3  train  foo
# 2  1.0 2025-09-18  1.0  3   test  foo
# 3  1.0 2025-09-18  1.0  3  train  foo

# %%
dataFrame2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
print(labels)
# Out:
# ['a', 'b', 'c']

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
series1 = pd.Series([1,2,3,4],index = [ 'sumit','komal','sangita','binod'])
print(series1)
# Out:
# sumit      1
# komal      2
# sangita    3
# binod      4
# dtype: int64

# %%
series2 = pd.Series([1,2,3,4],index = [ 'sumit','komal','sangita','bino',])
print(series2)
# Out:
# sumit      1
# komal      2
# sangita    3
# bino       4
# dtype: int64

# %%
series1 + series2
# Out:
# bino       NaN
# binod      NaN
# komal      4.0
# sangita    6.0
# sumit      2.0
# dtype: float64

# %%
df = pd.DataFrame(np.random.randn(5,4), ['A','B','C','D','E'], ['W','X','Y','Z'])
print(df)
# Out:
#           W         X         Y         Z
# A  0.624874 -0.663320 -0.116011  0.974014
# B  0.958897  0.017192 -0.909218  1.323052
# C -0.624402  0.172670  0.103820 -0.564333
# D  0.630655  0.293729 -0.155472  1.461285
# E  0.558161 -0.582267  1.182013  0.783241

# %%
df['Y']
# Out:
# A   -0.116011
# B   -0.909218
# C    0.103820
# D   -0.155472
# E    1.182013
# Name: Y, dtype: float64

# %%
df[['X','Y']]
# Out:
#           X         Y
# A -0.663320 -0.116011
# B  0.017192 -0.909218
# C  0.172670  0.103820
# D  0.293729 -0.155472
# E -0.582267  1.182013

# %%
df['K'] = df['W'] + df['Y']
print(df)
# Out:
#           W         X         Y         Z         K
# A  0.624874 -0.663320 -0.116011  0.974014  0.508863
# B  0.958897  0.017192 -0.909218  1.323052  0.049679
# C -0.624402  0.172670  0.103820 -0.564333 -0.520582
# D  0.630655  0.293729 -0.155472  1.461285  0.475183
# E  0.558161 -0.582267  1.182013  0.783241  1.740174

# %%
df.drop('K',axis=1)
# Out:
#           W         X         Y         Z
# A  0.624874 -0.663320 -0.116011  0.974014
# B  0.958897  0.017192 -0.909218  1.323052
# C -0.624402  0.172670  0.103820 -0.564333
# D  0.630655  0.293729 -0.155472  1.461285
# E  0.558161 -0.582267  1.182013  0.783241

# %%
df
# Out:
#           W         X         Y         Z         K
# A  0.624874 -0.663320 -0.116011  0.974014  0.508863
# B  0.958897  0.017192 -0.909218  1.323052  0.049679
# C -0.624402  0.172670  0.103820 -0.564333 -0.520582
# D  0.630655  0.293729 -0.155472  1.461285  0.475183
# E  0.558161 -0.582267  1.182013  0.783241  1.740174

# %%
df
# Out:
#           W         X         Y         Z         K
# A  0.624874 -0.663320 -0.116011  0.974014  0.508863
# B  0.958897  0.017192 -0.909218  1.323052  0.049679
# C -0.624402  0.172670  0.103820 -0.564333 -0.520582
# D  0.630655  0.293729 -0.155472  1.461285  0.475183
# E  0.558161 -0.582267  1.182013  0.783241  1.740174

# %%
df['K'] = df['W'] + df['Y']
print(df)
# Out:
#           W         X         Y         Z         K
# A  0.624874 -0.663320 -0.116011  0.974014  0.508863
# B  0.958897  0.017192 -0.909218  1.323052  0.049679
# C -0.624402  0.172670  0.103820 -0.564333 -0.520582
# D  0.630655  0.293729 -0.155472  1.461285  0.475183
# E  0.558161 -0.582267  1.182013  0.783241  1.740174

# %%
df['X'] = df['W'] + df['Y']
print(df)
# Out:
#           W         X         Y         Z         K
# A  0.624874  0.508863 -0.116011  0.974014  0.508863
# B  0.958897  0.049679 -0.909218  1.323052  0.049679
# C -0.624402 -0.520582  0.103820 -0.564333 -0.520582
# D  0.630655  0.475183 -0.155472  1.461285  0.475183
# E  0.558161  1.740174  1.182013  0.783241  1.740174

# %%
df.drop('K',axis=1,inplace=True)
print(df)
# Out:
#           W         X         Y         Z
# A  0.624874  0.508863 -0.116011  0.974014
# B  0.958897  0.049679 -0.909218  1.323052
# C -0.624402 -0.520582  0.103820 -0.564333
# D  0.630655  0.475183 -0.155472  1.461285
# E  0.558161  1.740174  1.182013  0.783241

# %%
df['X']      # selects column X
# Out:
# A    0.508863
# B    0.049679
# C   -0.520582
# D    0.475183
# E    1.740174
# Name: X, dtype: float64

# %%
df.loc['A']  # selects row A
# Out:
# W    0.624874
# X    0.508863
# Y   -0.116011
# Z    0.974014
# Name: A, dtype: float64

# %%
df['X']
# Out:
# A    0.508863
# B    0.049679
# C   -0.520582
# D    0.475183
# E    1.740174
# Name: X, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -0.624402
# X   -0.520582
# Y    0.103820
# Z   -0.564333
# Name: C, dtype: float64

# %%
print(df.loc['B','Y'])
# Out:
# -0.909218447174309

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  0.624874 -0.116011
# B  0.958897 -0.909218

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True   True  False   True
# B   True   True  False   True
# C  False  False   True  False
# D   True   True  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  0.624874  0.508863       NaN  0.974014
# B  0.958897  0.049679       NaN  1.323052
# C       NaN       NaN  0.103820       NaN
# D  0.630655  0.475183       NaN  1.461285
# E  0.558161  1.740174  1.182013  0.783241

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  0.624874  0.508863 -0.116011  0.974014
# B  0.958897  0.049679 -0.909218  1.323052
# D  0.630655  0.475183 -0.155472  1.461285
# E  0.558161  1.740174  1.182013  0.783241

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# A -0.116011  0.508863
# B -0.909218  0.049679
# D -0.155472  0.475183
# E  1.182013  1.740174

# %%
df[(df['W']>0) & (df['Y']>1)]
# Out:
#           W         X         Y         Z
# E  0.558161  1.740174  1.182013  0.783241

# %%
df[(df['W']>0) | (df['Y']>1)]
# Out:
#           W         X         Y         Z
# A  0.624874  0.508863 -0.116011  0.974014
# B  0.958897  0.049679 -0.909218  1.323052
# D  0.630655  0.475183 -0.155472  1.461285
# E  0.558161  1.740174  1.182013  0.783241

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  0.624874  0.508863 -0.116011  0.974014
# 1     B  0.958897  0.049679 -0.909218  1.323052
# 2     C -0.624402 -0.520582  0.103820 -0.564333
# 3     D  0.630655  0.475183 -0.155472  1.461285
# 4     E  0.558161  1.740174  1.182013  0.783241

# %%
mdata = pd.DataFrame({'A':[1,2,np.nan],
                    'B':[5 ,np.nan,np.nan],
                    'C':[1,2,3]})
print(mdata)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
mdata.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
mdata.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
mdata.dropna(axis=0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
print(mdata)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
mdata.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
mdata.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
mdata['A'].fillna(value=mdata['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
data = {'company' : ['Google','Google','Microsoft','microdoft','facebook','facebook'],
        'person' : ['sumit','komal','sangita','sneha','sonali','mayanak'],
        'sales' : [200,120,340,124,243,350]}
print(data)
# Out:
# {'company': ['Google', 'Google', 'Microsoft', 'microdoft', 'facebook', 'facebook'], 'person': ['sumit', 'komal', 'sangita', 'sneha', 'sonali', 'mayanak'], 'sales': [200, 120, 340, 124, 243, 350]}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      company   person  sales
# 0     Google    sumit    200
# 1     Google    komal    120
# 2  Microsoft  sangita    340
# 3  microdoft    sneha    124
# 4   facebook   sonali    243
# 5   facebook  mayanak    350

# %%
df.groupby('company').get_group('Google')
# Out:
#   company person  sales
# 0  Google  sumit    200
# 1  Google  komal    120

# %%
by_comp = df.groupby("company")

# %%
print(by_comp.min())
# Out:
#             person  sales
# company
# Google       komal    120
# Microsoft  sangita    340
# facebook   mayanak    243
# microdoft    sneha    124

# %%
print(by_comp.max())
# Out:
#             person  sales
# company
# Google       sumit    200
# Microsoft  sangita    340
# facebook    sonali    350
# microdoft    sneha    124

# %%
by_comp.describe()
# Out:
#           sales
#           count   mean        std    min     25%    50%     75%    max
# company
# Google      2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# Microsoft   1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0
# facebook    2.0  296.5  75.660426  243.0  269.75  296.5  323.25  350.0
# microdoft   1.0  124.0        NaN  124.0  124.00  124.0  124.00  124.0

# %%
by_comp.describe().transpose()
# Out:
# company          Google  Microsoft    facebook  microdoft
# sales count    2.000000        1.0    2.000000        1.0
#       mean   160.000000      340.0  296.500000      124.0
#       std     56.568542        NaN   75.660426        NaN
#       min    120.000000      340.0  243.000000      124.0
#       25%    140.000000      340.0  269.750000      124.0
#       50%    160.000000      340.0  296.500000      124.0
#       75%    180.000000      340.0  323.250000      124.0
#       max    200.000000      340.0  350.000000      124.0
