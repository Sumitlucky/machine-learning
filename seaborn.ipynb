# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.mean,color='red')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips,color = 'green')
sns.countplot(x='smoker',data=tips,color = 'yellow')
sns.countplot(x='size',data=tips,color = 'red')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow')
# Out:
# /tmp/ipython-input-3391461266.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow' ,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips, palette='rainbow')
# Out:
# /tmp/ipython-input-2994872152.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day", y="total_bill", data=tips, palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue='sex', palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day" , y="total_bill" , data=tips,hue='sex',split=True,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue='sex',palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=False,hue='sex',palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue='sex',palette='rainbow' ,dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,palette='rainbow')
# Out:
# /tmp/ipython-input-1982535712.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day",y="total_bill",data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,palette='rainbow' , dodge= True)
# Out:
# /tmp/ipython-input-4081954036.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day",y="total_bill",data=tips,palette='rainbow' , dodge= True)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",hue='sex',data=tips,palette='rainbow' , dodge= True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day" , y="tip" , data=tips,palette='rainbow')
sns.swarmplot(x="day",y="tip",data=tips,color = 'black' , size=3)
# Out:
# /tmp/ipython-input-3866913991.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day" , y="tip" , data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x="day" , y="sex" , data=tips,palette='rainbow')
sns.swarmplot(x="day",y="sex",data=tips,color = 'red' , size=3)
# Out:
# /tmp/ipython-input-1486909837.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day" , y="sex" , data=tips,palette='rainbow')
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 51.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 48.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.violinplot(x="time" , y="tip" , data=tips,palette='rainbow')
sns.swarmplot(x="time",y="tip",data=tips,color = 'orange' , size=3)
# Out:
# /tmp/ipython-input-4263360610.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="time" , y="tip" , data=tips,palette='rainbow')
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.catplot(x="size",y="total_bill",data=tips,kind='bar',palette='rainbow')
# Out:
# /tmp/ipython-input-729125671.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="size",y="total_bill",data=tips,kind='bar',palette='rainbow')

# %%
sns.distplot(tips['tip'],color = 'red')
# Out:
# /tmp/ipython-input-1016221564.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'],color = 'red')
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips['tip'],color = 'green',kde=False)
# Out:
# /tmp/ipython-input-3523452329.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'],color = 'green',kde=False)
# <Axes: xlabel='tip'>

# %%
tips = sns.load_dataset("tips")
sns.jointplot(x="total_bill", y="tip", data=tips, kind="scatter")
plt.show()

# %%
tips = sns.load_dataset("tips")
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
plt.show()

# %%
tips = sns.load_dataset("tips")
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde")
plt.show()

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
sns.rugplot(tips['total_bill'])
plt.show()
